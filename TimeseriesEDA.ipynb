# %%
import pandas_datareader as pdr
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
# Fetch data for TSLA from Yahoo Finance using yfinance
tsla_data = yf.download('TSLA')
tsla_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-02-12  192.110001  194.729996  187.279999  188.130005  188.130005
# 2024-02-13  183.990005  187.259995  182.110001  184.020004  184.020004
# 2024-02-14  185.300003  188.889999  183.350006  188.710007  188.710007
# 2024-02-15  189.160004  200.880005  188.860001  200.449997  200.449997
# 2024-02-16  202.059998  203.169998  197.399994  199.949997  199.949997
#
#                Volume
# Date
# ...

# %%
tsla_data.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(xlim=['2019-04-01','2024-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
index=tsla_data.loc['2020-01-01': '2021-09-01'].index
share_open=tsla_data.loc['2020-01-01':'2021-09-01']['Open']

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
#preventing the overlap
axis.plot(index, share_open)

# %%
#date-time index
tsla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3433 entries, 2010-06-29 to 2024-02-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3433 non-null   float64
#  1   High       3433 non-null   float64
#  2   Low        3433 non-null   float64
#  3   Close      3433 non-null   float64
#  4   Adj Close  3433 non-null   float64
#  5   Volume     3433 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 316.8 KB

# %%
df_tsla=tsla_data.reset_index()

# %%
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3433 entries, 0 to 3432
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3433 non-null   datetime64[ns]
#  1   Open       3433 non-null   float64
#  2   High       3433 non-null   float64
#  3   Low        3433 non-null   float64
#  4   Close      3433 non-null   float64
#  5   Adj Close  3433 non-null   float64
#  6   Volume     3433 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 187.9 KB

# %%
df_tsla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3428 2024-02-12  192.110001  194.729996  187.279999  188.130005  188.130005
# 3429 2024-02-13  183.990005  187.259995  182.110001  184.020004  184.020004
# 3430 2024-02-14  185.300003  188.889999  183.350006  188.710007  188.710007
# 3431 2024-02-15  189.160004  200.880005  188.860001  200.449997  200.449997
# 3432 2024-02-16  202.059998  203.169998  197.399994  199.949997  199.949997
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df_tesla=df_tsla.set_index('Date',drop=True)

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-02-12  192.110001  194.729996  187.279999  188.130005  188.130005
# 2024-02-13  183.990005  187.259995  182.110001  184.020004  184.020004
# 2024-02-14  185.300003  188.889999  183.350006  188.710007  188.710007
# 2024-02-15  189.160004  200.880005  188.860001  200.449997  200.449997
# 2024-02-16  202.059998  203.169998  197.399994  199.949997  199.949997
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %% [markdown]
# ## time resampling

# %%
df_tesla.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
df_tesla.resample(rule='A').min()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
##quaterly start frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
##Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='BA').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.resample(rule='BA').max()['High']
# Out:
# Date
# 2010-12-31      2.428000
# 2011-12-30      2.333333
# 2012-12-31      2.663333
# 2013-12-31     12.966667
# 2014-12-31     19.427999
# 2015-12-31     19.110001
# 2016-12-30     17.955999
# 2017-12-29     25.974001
# 2018-12-31     25.830667
# 2019-12-31     29.020666
# 2020-12-31    239.573334
# 2021-12-31    414.496674
# 2022-12-30    402.666656
# 2023-12-29    299.290009
# 2024-12-31    251.250000
# Freq: BA-DEC, Name: High, dtype: float64

# %%
df_tesla.resample(rule='BQS').max()['High']
# Out:
# Date
# 2010-04-01      2.028000
# 2010-07-01      1.728000
# 2010-10-01      2.428000
# 2011-01-03      1.914000
# 2011-04-01      2.100000
# 2011-07-01      2.029333
# 2011-10-03      2.333333
# 2012-01-02      2.663333
# 2012-04-02      2.564667
# 2012-07-02      2.400000
# 2012-10-01      2.386667
# 2013-01-01      2.666667
# 2013-04-01      7.660000
# 2013-07-01     12.966667
# 2013-10-01     12.948667
# 2014-01-01     17.666668
# 2014-04-01     16.299334
# 2014-07-01     19.427999
# 2014-10-01     17.702667
# 2015-01-01     15.032000
# 2015-04-01     18.094000
# 2015-07-01     19.110001
# 2015-10-01     16.656000
# 2016-01-01     15.992000
# 2016-04-01     17.955999
# 2016-07-01     15.775333
# 2016-10-03     14.920000
# 2017-01-02     19.159332
# 2017-04-03     25.799334
# 2017-07-03     25.974001
# 2017-10-02     24.200001
# 2018-01-01     24.033333
# 2018-04-02     24.915333
# 2018-07-02     25.830667
# 2018-10-01     25.299334
# 2019-01-01     23.466667
# ...

# %% [markdown]
# ## time plotting

# %%
##plotting
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max() .plot(kind='bar',figsize= (30,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## rolling

# %%
df_tesla['High'].rolling(11).mean().head(20)
# measures the mean in the window sixe of 11 here so first 11 items are nan
# can do mean, min, max anything
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13         NaN
# 2010-07-14    1.414242
# 2010-07-15    1.393030
# 2010-07-16    1.337758
# 2010-07-19    1.315515
# 2010-07-20    1.307939
# 2010-07-21    1.313394
# 2010-07-22    1.341394
# 2010-07-23    1.365879
# 2010-07-26    1.387697
# 2010-07-27    1.406545
# Name: High, dtype: float64

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30) .mean()

# %%
df_tesla.head (31)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open:10 days rolling']=df_tesla['Open'].rolling(window=10, min_periods=1) .mean()
df_tesla['Open:50 days rolling']=df_tesla['Open'].rolling(window=50, min_periods=1) .mean()

# %%
df_tesla[['Open', 'Open:10 days rolling','Open:30 days rolling','Open:50 days rolling']].plot(xlim=['2019-01-01','2024-01-01'],figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## expanding

# %%
df_tesla['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## EWMA

# %%
## EMA tesla shares
# Let's smoothing factor - 0.1
df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False) .mean ()
df_tesla['EMA_0.3'] = df_tesla['Open'].ewm(alpha=0.3, adjust=False) .mean ()

# %%
df_tesla[['Open', 'EMA_0.1','EMA_0.3']].plot(xlim= ['2020-01-01', '2021-01-01'], figsize=(15,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['EMA_5days'] = df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open', 'EMA_5days']].plot(xlim=['2019-01-01','2024-01-01'],figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla[['Open', 'EMA_5days','EMA_0.1']].plot(xlim=['2019-01-01','2024-01-01'],figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>
